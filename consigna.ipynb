# %% [markdown]
# # Trabajo Práctico: Equidad en Aprendizaje Automático
# **1er cuatrimestre 2026**
# Fecha de última actualización: 06/04/2026

# %% [markdown]
# ## 1. Conjunto de datos
#
# | Nombre del dataset | Fuente | Enunciado | Variable protegida | Entidad |
# |---|---|---|---|---|
# | Open University Learning Analytics | [Enlace](https://archive.ics.uci.edu/dataset/349/open+university+learning+analytics+dataset) | El objetivo del proyecto es mejorar la tasa de aprobación... | género, discapacidad | Universidad |
# | German Credit | [Enlace](https://archive.ics.uci.edu/dataset/144/statlog+german+credit+data) | El objetivo del proyecto es optimizar el proceso de evaluación... | género, edad | Banco |
# | Bank marketing | [Enlace](https://archive.ics.uci.edu/dataset/222/bank+marketing) | El objetivo del proyecto es incrementar la tasa de suscripción... | estado civil, edad | Banco |
# | Riesgo de diabetes | [Enlace](https://archive.ics.uci.edu/dataset/529/early+stage+diabetes+risk+prediction+dataset) | El objetivo del proyecto es mejorar la detección temprana... | género, edad | Hospital |

# %% [markdown]
# ## 2. Ejercicios

# %% [markdown]
# ### Ejercicio 1
# a) Obtener el conjunto de datos del repositorio correspondiente.
#
# b) Buscando información en fuentes confiables y citándolas, contestar, al menos, las siguientes preguntas propuestas en el trabajo *Datasheets for Datasets* para conocer un poco mejor a este conjunto de datos:
#    - **i) Motivación:**
#      1. ¿Con qué propósito se creó el conjunto de datos? ¿Era para una tarea específica? ¿Había una brecha específica que necesitaba ser cubierta? Proporcione una descripción.
#      2. ¿Quién creó el conjunto de datos?
#    - **ii) Composición:**
#      1. ¿Qué representan las instancias que componen el conjunto de datos? Proporcione una descripción.
#    - **iii) Proceso de recopilación:**
#      1. ¿Cómo se adquirieron los datos asociados con cada instancia?
#    - **iv) Preprocesamiento/limpieza/etiquetado:**
#      1. ¿Se realizó algún preprocesamiento/limpieza/etiquetado de los datos?
#    - **v) Usos:**
#      1. ¿Se ha utilizado ya el conjunto de datos para alguna tarea?
#      2. ¿Existe un repositorio que enlace a alguno o todos los documentos o sistemas que utilizan el conjunto de datos?
#
# c) Realizar un análisis exploratorio del conjunto de datos. Por ejemplo, explorar la distribución de las etiquetas de acuerdo a las variables protegidas.
#
# d) Identificar sesgos potenciales (por ejemplo, representación de género en préstamos aprobados).

# %% [markdown]
# ### Ejercicio 2
# a) Elegir algún modelo clásico de clasificación (por ejemplo: random forest o regresión logística). Entrenar y evaluar su performance usando las métricas clásicas (precision, recall, accuracy, f1-score) y crear la matriz de confusión. Interpretar los resultados obtenidos hasta el momento.
#
# b) Suponiendo que su equipo forma parte de la entidad asignada en la Tabla y su objetivo planteado en el enunciado ¿cuál de los errores consideran que es peor en este caso? Justificar.

# %% [markdown]
# ### Ejercicio 3
# En lo que sigue, consideraremos que la variable protegida a analizar será **género**.
# Basándonos en trabajos que señalan ciertos sesgos de genéro, se propone:
#
# a) Describir con palabras cómo se interpretan en este contexto los criterios de fairness vistos en clase: Statistical Parity, Equalized Odds, Equal Opportunity y Predictive Parity.
#
# b) Considerando como medida de disparidad el módulo de la diferencia y seleccionando un umbral definido por ustedes, analizar si el modelo inicial es fair para cada una de las posibles definiciones de fairness estudiadas en el inciso anterior.
#
# c) Recordando que forman parte de la entidad asignada en cada conjunto de datos, ¿cuál de los criterios de fairness le parece relevante en este contexto? Justificar su elección.

# %% [markdown]
# ### Ejercicio 4
# En este apartado exploraremos técnicas para mejorar la equidad del modelo creado.
#
# a) Seleccionar al menos 2 técnicas de Mitigación de sesgos vistas en clase, entrenar el modelo ajustado y evaluar su performance usando las métricas clásicas (precision, recall, accuracy, f1-score) y crear la matriz de confusión. Interpretar los resultados obtenidos hasta el momento.
#
# b) Evaluar su performance utilizando las mismas métricas y evaluaciones de equidad del inciso 3.

# %% [markdown]
# ### Ejercicio 5
# a) Comparar los resultados del modelo original y ajustado.
#
# b) Discutir mejoras en la fairness del modelo y las métricas de performance.
#
# c) Reflexionar sobre cómo estos cambios impactan en aplicaciones del mundo real y la importancia de la equidad en machine learning.

# %% [markdown]
# ## 3. Presentación Preliminar
# - **Fecha:** 16/04
# - **Qué se espera:** Que detallen el avance del trabajo...
